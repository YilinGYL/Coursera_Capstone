# %% [markdown]
# # Capstone Project:
# # Best Places to Travel & Eat in London for First-time Visitor

# %% [markdown]
# ## 1. Introduction

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import csv # library to handle csv files

import geocoder as geocoder
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

from bs4 import BeautifulSoup
import requests

print('Libraries imported.')

# %% [markdown]
# ## 2. Data Collection
# ### 2.1. Get the recommended-places-to-visit Data

# %%
#Get the data with beautifulsoup  https://foursquare.com/gmissawa/list/places-to-visit-in-london
df_venue = pd.read_csv("df_venue.csv")
df_venue.sort_values('rating', ascending=False, inplace = True)
df_venue.head()
# Out:
#     Unnamed: 0  location.lat  location.lng location.postalCode  \
# 18          16     51.507781     -0.162392              W2 2TP
# 14          27     51.477521      0.000858            SE10 9NF
# 72          45     51.689539     -0.419315            WD25 7LR
# 68           7     51.505550     -0.075338             SE1 2UP
# 40          15     51.501122     -0.177417             SW7 2AP
#
#                                                  name  rating  likes.count
# 18                                          Hyde Park     9.6        11445
# 14                                     Greenwich Park     9.6         1358
# 72  Warner Bros. Studio Tour London - The Making o...     9.6         2837
# 68                                       Tower Bridge     9.5         5471
# 40                                  Royal Albert Hall     9.5         2536

# %%
print(df_venue.shape)
print('The dataframe has {} locations'.format(
        len(df_venue['name'].unique()),))
# Out:
# (78, 7)
# The dataframe has 78 locations

# %% [markdown]
# ### Create a map of London with the recommended places using latitude and longitude values

# %%
for lat1, lng1, name in zip(df_venue['location.lat'], df_venue['location.lng'], df_venue['name']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat1, lng1],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#FF5733',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  

map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# ### 3.1. Based on current location to recommend a place to go

# %%
###################
#Define a function to calculate the distance between two points based on longitude and latitude
def calculate_distance(lat1, lon1, lat2, lon2):

    from math import sin, cos, sqrt, atan2, radians

    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c

    #print("Result:", distance)

    return distance

# %%
# Use a random start point 
# I used a highest-ranked hotel location as the starting point
current_lat = 51.5168
current_log = 0.1360

# %%
# Calculate the distnace based on the latitude and longitude
for i in range (len(df_venue)):
    place = df_venue.iloc[i, :]
    lat2 = place['location.lat']
    log2 = place['location.lng']
    df_venue.loc[i,'distance'] = calculate_distance(current_lat, current_log, lat2, log2)

# Sort the dataframe by distance
df_venue_sort = df_venue.sort_values(by='distance', ascending=True)

df_venue_sort.head(10)
# Out:
#     Unnamed: 0  location.lat  location.lng location.postalCode  \
# 1           19     51.512841     -0.127896            WC2H 9ND
# 56          35     51.506912     -0.194801              W8 7LN
# 3           32     51.519800     -0.093969            EC2Y 8DS
# 18          16     51.507781     -0.162392              W2 2TP
# 61           1     51.503287     -0.119594             SE1 7PB
# 59          25     51.511718     -0.125695            WC2E 9EB
# 52          33     51.179060     -1.826198             SP4 7DE
# 72          45     51.689539     -0.419315            WD25 7LR
# 16          29     51.403235     -0.337400             KT8 9AU
# 21          12     51.531371     -0.126022             NW1 2QP
#
#                                                  name  rating  likes.count  \
# 1                                 Ambassadors Theatre     8.1           73
# 56                                 The Churchill Arms     8.9          718
# 3                                Barbican Art Gallery     9.2          273
# 18                                          Hyde Park     9.6        11445
# 61                                     The London Eye     9.2         6506
# 59                                    The Lamb & Flag     8.5          454
# 52                                         Stonehenge     8.7         1695
# 72  Warner Bros. Studio Tour London - The Making o...     9.6         2837
# 16                               Hampton Court Palace     9.3          775
# 21  London St Pancras International Railway Statio...     8.9         2917
#
#      distance
# 1   10.327738
# 56  10.445538
# 3   14.683319
# 18  14.724101
# 61  15.099482
# 59  15.388385
# 52  15.712717
# 72  15.884810
# 16  15.918907
# 21  15.920634

# %%
# Make a recommendation
print("The closest place to go is: ", df_venue_sort.iloc[0,:]['name'])
print("The rating is: ", df_venue_sort.iloc[0,:]['rating'])

#Save the latitude and longitude of this place for restaurant recommendation
# Out:
# The closest place to go is:  Ambassadors Theatre
# The rating is:  8.1

# %% [markdown]
# ### 3.1. Recommend a restaurant

# %%
#0.Define Foursquare 
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EL0QYZH3NAVAKDR2M5EGMSKEFEM3BXPO2CHPEMNR4GDAF3VL
# CLIENT_SECRET:MYTF243JWF3F1RLYHNLQQXNQHBHMYFKEJJWAG0QKN0TTJRRS

# %%
#1.Based on the venue just visited
venue_latitude = df_venue_sort.iloc[0,:]['location.lat']
venue_longitude = df_venue_sort.iloc[0,:]['location.lng']

venue_name = df_venue_sort.iloc[0,:]['name']

print('Latitude and longitude values of {} are {}, {}.'.format(venue_name, 
                                                               venue_latitude, 
                                                               venue_longitude))
# Out:
# Latitude and longitude values of Ambassadors Theatre are 51.512841064253024, -0.1278958930930689.

# %%
#2.Recommend food related venue in a radius of 100 around the most-liked place

#Foursquare service for recommendation
LIMIT = 50 # limit of number of venues returned by Foursquare API
radius = 100 # define radius
intent = 'food'
sortByDistance = 'true'

#GET https://api.foursquare.com/v2/search/recommendations

#1. Write the url with important parameters:
url_r = 'https://api.foursquare.com/v2/search/recommendations?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&intent={}&sortByDistance={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION,    
    venue_latitude,
    venue_longitude,
    radius,
    LIMIT,
    intent,
    sortByDistance)

url_r
# Out:
# 'https://api.foursquare.com/v2/search/recommendations?&client_id=EL0QYZH3NAVAKDR2M5EGMSKEFEM3BXPO2CHPEMNR4GDAF3VL&client_secret=MYTF243JWF3F1RLYHNLQQXNQHBHMYFKEJJWAG0QKN0TTJRRS&v=20180605&ll=51.512841064253024,-0.1278958930930689&radius=100&limit=50&intent=food&sortByDistance=true'

# %%
recommend = requests.get(url_r).json()
# recommend
venues = recommend['response']['group']['results']
venues
# Out:
# [{'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bc4',
#   'photo': {'createdAt': 1373318483,
#    'height': 960,
#    'id': '51db2d53498ebf7acc10f8df',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/2519409_KnZ4IMDhzB62VOvswk8and-Ni3CUvOCaOwn2rFHzV2g.jpg',
#    'visibility': 'public',
#    'width': 720},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 0,
#        'canonicalUrl': 'https://foursquare.com/item/573ce3ea498e4b8918686d6b',
#        'createdAt': 1463608298,
#        'disagreeCount': 0,
#        'id': '573ce3ea498e4b8918686d6b',
#        'logView': True,
#        'text': 'For starters The barbeque squid salad worth chorizo which was simply incredible. Mains was the herb roasted monkfish - hands down best monkfish I have ever had!',
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Becky',
#         'id': '73231888',
#         'lastName': 'J',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/73231888-Y4HCHDIYQFHOPY5D.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'id': '52e81612bcbc57f1066b7a05',
#      'name': 'English Restaurant',
#      'pluralName': 'English Restaurants',
#      'primary': True,
#      'shortName': 'English'}],
#    'dislike': False,
#    'id': '4b5344aef964a5200c9527e3',
#    'location': {'address': '1-5 West St',
#     'cc': 'GB',
#     'city': 'London',
#     'country': 'United Kingdom',
#     'crossStreet': 'Litchfield St',
#     'distance': 7,
#     'formattedAddress': ['1-5 West St (Litchfield St)',
#      'London',
#      'Greater London',
#      'WC2H 9NQ',
#      'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.51279973860704,
#       'lng': -0.12798146580711955}],
#     'lat': 51.51279973860704,
#     'lng': -0.12798146580711955,
#     'postalCode': 'WC2H 9NQ',
#     'state': 'Greater London'},
#    'name': 'The Ivy Restaurant',
#    'ok': False}},
#  {'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bc5',
#   'photo': {'createdAt': 1568878969,
#    'height': 1920,
#    'id': '5d833179b49651000863184d',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/113883147_jPWA9hlLlfwXXuVT2aS6NnVGTZSTMts0b-KhtQBChoY.jpg',
#    'visibility': 'public',
#    'width': 1440},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 3,
#        'canonicalUrl': 'https://foursquare.com/item/55ecae51498ec537de13d925',
#        'createdAt': 1441574481,
#        'disagreeCount': 0,
#        'id': '55ecae51498ec537de13d925',
#        'lastUpvoteTimestamp': 1574606923,
#        'lastVoteText': 'Upvoted Nov 24, 2019',
#        'logView': True,
#        'text': "fall off bone short ribs, perfect burger with perfect bun, bacon jam.. Sweet potato fries. Tried the harissa aubergine which blew our mind even for people who don't typically like aubergine/eggplant.",
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Carrie',
#         'id': '11802186',
#         'lastName': 'S',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/3HS3N4GN2QUTTRIR.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'id': '52e81612bcbc57f1066b7a05',
#      'name': 'English Restaurant',
#      'pluralName': 'English Restaurants',
#      'primary': True,
#      'shortName': 'English'}],
#    'dislike': False,
#    'id': '54172b0f498e587dba2832f7',
#    'location': {'address': "4A Upper St Martin's Ln",
#     'cc': 'GB',
#     'city': 'London',
#     'country': 'United Kingdom',
#     'distance': 74,
#     'formattedAddress': ["4A Upper St Martin's Ln",
#      'London',
#      'Greater London',
#      'WC2H 9NY',
#      'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.512276,
#       'lng': -0.127321}],
#     'lat': 51.512276,
#     'lng': -0.127321,
#     'postalCode': 'WC2H 9NY',
#     'state': 'Greater London'},
#    'name': 'Tredwells',
#    'ok': False}},
#  {'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bc6',
#   'photo': {'createdAt': 1374703035,
#    'height': 612,
#    'id': '51f04dbb498e7e365901354d',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/29133099_2Aw7wedOvoYMuPtycorpf6D1AfUArXZNhsn3v9tzGkw.jpg',
#    'visibility': 'public',
#    'width': 612},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 0,
#        'canonicalUrl': 'https://foursquare.com/item/56ea8bf1498ead43ef9facb2',
#        'createdAt': 1458211825,
#        'disagreeCount': 0,
#        'id': '56ea8bf1498ead43ef9facb2',
#        'logView': True,
#        'text': 'Unlimited porridge and chai for breakfast! Full of flavour and a beautiful calming start to the day.',
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Stephanie',
#         'id': '147912176',
#         'lastName': 'M',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/147912176_0SdPrZ3I_TbiClqtArYcQ80brCR8UA1Bejq9gyg6PaY0gyJAReOtqletHPFQGv3pfPyKYzWd3.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d10f941735',
#      'name': 'Indian Restaurant',
#      'pluralName': 'Indian Restaurants',
#      'primary': True,
#      'shortName': 'Indian'}],
#    'dislike': False,
#    'id': '4c31c371a0ced13a150d146e',
#    'location': {'address': '12 Upper St Martin’s Ln',
#     'cc': 'GB',
#     'city': 'Covent Garden',
#     'country': 'United Kingdom',
#     'distance': 82,
#     'formattedAddress': ['12 Upper St Martin’s Ln',
#      'Covent Garden',
#      'Greater London',
#      'WC2H 9FB',
#      'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.51243,
#       'lng': -0.12690805}],
#     'lat': 51.51243,
#     'lng': -0.12690805,
#     'neighborhood': 'City of Westminster',
#     'postalCode': 'WC2H 9FB',
#     'state': 'Greater London'},
#    'name': 'Dishoom',
#    'ok': False}},
#  {'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bc7',
#   'photo': {'createdAt': 1574282270,
#    'height': 1920,
#    'id': '5dd5a41e22b5cf00079c980e',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/468374510_Gn4fZwF-UUpj1Hu3FEuAhQg5XqzNfHWbAjp_Uk_SeMg.jpg',
#    'visibility': 'public',
#    'width': 1440},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 0,
#        'canonicalUrl': 'https://foursquare.com/item/582579551942be3c24b629f3',
#        'createdAt': 1478850901,
#        'disagreeCount': 0,
#        'id': '582579551942be3c24b629f3',
#        'logView': True,
#        'text': "Very tasty fried chicken. Had disco wings, colonel bun and fries. The buns are huge so wasn't able to finish everything! Kewpie mayo dip is yummy.",
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Jusna',
#         'id': '418953',
#         'lastName': 'B',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/418953-1CB3FIYSPCAG1325.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#       'suffix': '.png'},
#      'id': '4d4ae6fc7a7b7dea34424761',
#      'name': 'Fried Chicken Joint',
#      'pluralName': 'Fried Chicken Joints',
#      'primary': True,
#      'shortName': 'Fried Chicken'}],
#    'dislike': False,
#    'id': '57e6cee7498ec100a83cfd3c',
#    'location': {'address': '1 Earlham St',
#     'cc': 'GB',
#     'city': 'West End',
#     'country': 'United Kingdom',
#     'distance': 89,
#     'formattedAddress': ['1 Earlham St',
#      'West End',
#      'Greater London',
#      'WC2H 9LL',
#      'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.51362436953327,
#       'lng': -0.12815892822155797}],
#     'lat': 51.51362436953327,
#     'lng': -0.12815892822155797,
#     'postalCode': 'WC2H 9LL',
#     'state': 'Greater London'},
#    'name': "Chick 'n' Sours",
#    'ok': False}},
#  {'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bc9',
#   'photo': {'createdAt': 1577881055,
#    'height': 1920,
#    'id': '5e0c8ddfb1710200082a419e',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/163526_J2NmZ1i3nNhHac_JXzAR5DnrvihAlRCy3rLgLEp1mMU.jpg',
#    'visibility': 'public',
#    'width': 1440},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 1,
#        'canonicalUrl': 'https://foursquare.com/item/5b26def30d173f002c64b94b',
#        'createdAt': 1529274099,
#        'disagreeCount': 0,
#        'id': '5b26def30d173f002c64b94b',
#        'logView': True,
#        'text': 'Cardamom bun was heavenly! Will definitely return when next in london to try the cinnamon and vanilla variations.',
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Cam_in_Bris',
#         'id': '568817',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/4FQF5NHX4NUFZOXK.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'primary': True,
#      'shortName': 'Bakery'}],
#    'dislike': False,
#    'id': '560d0db9498e57efd528f261',
#    'location': {'address': '8 Earlham St',
#     'cc': 'GB',
#     'country': 'United Kingdom',
#     'distance': 89,
#     'formattedAddress': ['8 Earlham St', 'WC2H 9RY', 'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.51352,
#       'lng': -0.128575}],
#     'lat': 51.51352,
#     'lng': -0.128575,
#     'postalCode': 'WC2H 9RY'},
#    'name': 'Fabrique',
#    'ok': False}},
#  {'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bcb',
#   'photo': {'createdAt': 1373624016,
#    'height': 720,
#    'id': '51dfd6d0498eba3c1259063a',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/31641612_5N_BkRCrQZ3yqm3tHG4GVE1e4Sc6Os7SICraEK10JhU.jpg',
#    'visibility': 'public',
#    'width': 720},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 0,
#        'canonicalUrl': 'https://foursquare.com/item/4e67556f52b1ca65dc19689f',
#        'createdAt': 1315394927,
#        'disagreeCount': 0,
#        'id': '4e67556f52b1ca65dc19689f',
#        'logView': True,
#        'text': 'Seconding the veggie brekkie - better than the meat one and I love my meat',
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Emma',
#         'id': '1819516',
#         'lastName': 'G',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/I5KSTIIG0JVGD4V5.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'id': '52e81612bcbc57f1066b7a05',
#      'name': 'English Restaurant',
#      'pluralName': 'English Restaurants',
#      'primary': True,
#      'shortName': 'English'}],
#    'dislike': False,
#    'id': '4d440bf1c3e5f04d0a219620',
#    'location': {'address': "28 St Martin's Courtyard",
#     'cc': 'GB',
#     'city': 'Covent Garden',
#     'country': 'United Kingdom',
#     'crossStreet': "Upper St Martin's Ln",
#     'distance': 95,
#     'formattedAddress': ["28 St Martin's Courtyard (Upper St Martin's Ln)",
#      'Covent Garden',
#      'Greater London',
#      'WC2E 9AB',
#      'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.51255465283461,
#       'lng': -0.12659992255283425}],
#     'lat': 51.51255465283461,
#     'lng': -0.12659992255283425,
#     'postalCode': 'WC2E 9AB',
#     'state': 'Greater London'},
#    'name': "Bill's Restaurant",
#    'ok': False}},
#  {'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bce',
#   'photo': {'createdAt': 1502141053,
#    'height': 1920,
#    'id': '5988da7d82a75040aae49024',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/11209609_X7btW_hqTf0HuY89RvyTalv20zZOyvvx-tAEWKHNowI.jpg',
#    'visibility': 'public',
#    'width': 1440},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 4,
#        'canonicalUrl': 'https://foursquare.com/item/5a176c48bb8d3641ce525558',
#        'createdAt': 1511484488,
#        'disagreeCount': 0,
#        'id': '5a176c48bb8d3641ce525558',
#        'lastUpvoteTimestamp': 1571598381,
#        'lastVoteText': 'Upvoted Oct 20, 2019',
#        'logView': True,
#        'text': 'Almost as good as the one in Fashion Island in the OC in California... the portions are smaller but the taste is the same great kind! The lettuce wrap is to die for! Great service too!',
#        'todo': {'count': 1},
#        'type': 'user',
#        'user': {'firstName': 'iSponsor',
#         'id': '2793655',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/2793655-1WCZZQ0AN03J2SOA.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'primary': True,
#      'shortName': 'Chinese'}],
#    'dislike': False,
#    'id': '5980dcd02e26804a157bb9a2',
#    'location': {'address': '10 Great Newport St',
#     'cc': 'GB',
#     'city': 'London',
#     'country': 'United Kingdom',
#     'distance': 98,
#     'formattedAddress': ['10 Great Newport St',
#      'London',
#      'Greater London',
#      'WC2H 9JL',
#      'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.51195842695266,
#       'lng': -0.12784570686571584}],
#     'lat': 51.51195842695266,
#     'lng': -0.12784570686571584,
#     'postalCode': 'WC2H 9JL',
#     'state': 'Greater London'},
#    'name': "P. F. Chang's",
#    'ok': False}},
#  {'displayType': 'venue',
#   'id': '5e16eeb4e79aa500072e8bd0',
#   'photo': {'createdAt': 1578174653,
#    'height': 1920,
#    'id': '5e1108bd79bd090008bbc8c6',
#    'prefix': 'https://fastly.4sqi.net/img/general/',
#    'suffix': '/541233754__XlY2EhvkOA-fLnEOLdhin6QkSjPn1VrrTY30QxCrvI.jpg',
#    'visibility': 'public',
#    'width': 1440},
#   'snippets': {'count': 1,
#    'items': [{'detail': {'object': {'agreeCount': 0,
#        'canonicalUrl': 'https://foursquare.com/item/5de39872b5562800083d1d7b',
#        'createdAt': 1575196786,
#        'disagreeCount': 0,
#        'id': '5de39872b5562800083d1d7b',
#        'logView': True,
#        'text': 'Great and tasty burgers. Classic Shake Shack.',
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Martin',
#         'id': '60485531',
#         'lastName': 'J',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/60485531_D2TU4sEa_1Jl3lYnaA1oF4FayqzMJchoptId2ctOzP_is6clhXwj3fAvl0YkCymcyx0G-7t8G.jpg'}}},
#       'type': 'tip'}}]},
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d16c941735',
#      'name': 'Burger Joint',
#      'pluralName': 'Burger Joints',
#      'primary': True,
#      'shortName': 'Burgers'}],
#    'dislike': False,
#    'id': '59e85fbd6e4650734436499a',
#    'location': {'address': '1 Cambridge Circus',
#     'cc': 'GB',
#     'city': 'Soho',
#     'country': 'United Kingdom',
#     'distance': 98,
#     'formattedAddress': ['1 Cambridge Circus',
#      'Soho',
#      'Greater London',
#      'WC2H 8PA',
#      'United Kingdom'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 51.51331319280172,
#       'lng': -0.12910283680030188}],
#     'lat': 51.51331319280172,
#     'lng': -0.12910283680030188,
#     'postalCode': 'WC2H 8PA',
#     'state': 'Greater London'},
#    'name': 'Shake Shack Soho',
#    'ok': False,
#    'venuePage': {'id': '566490020'}}}]

# %% [markdown]
# ### 3.4. Cluster the restaurant into 5 clusters Recommed based on ratings/distances/likes (three lists recommendation)

# %%
nearby_food = json_normalize(venues) # flatten JSON
nearby_food

# filter columns
filtered_columns = ['venue.name', 'venue.categories','venue.location.distance', 'venue.location.lat', 'venue.location.lng','venue.id' ]
nearby_food_filtered =nearby_food.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
nearby_food_filtered['categories'] = nearby_food_filtered.apply(get_category_type, axis=1)

nearby_food_filtered.head(20)
#nearby_venues.shape

#keep the index of the venues for later use
nearby_food_filtered = nearby_food_filtered.rename_axis('SerialNum').reset_index()

nearby_food_filtered.columns = ['serialNum', 'name','categories_', 'distance', 'lat', 'lng', 'id', 'categories']

# %%
nearby_food_filtered
# Out:
#    serialNum                name  \
# 0          0  The Ivy Restaurant
# 1          1           Tredwells
# 2          2             Dishoom
# 3          3     Chick 'n' Sours
# 4          4            Fabrique
# 5          5   Bill's Restaurant
# 6          6       P. F. Chang's
# 7          7    Shake Shack Soho
#
#                                          categories_  distance        lat  \
# 0  [{'id': '52e81612bcbc57f1066b7a05', 'name': 'E...         7  51.512800
# 1  [{'id': '52e81612bcbc57f1066b7a05', 'name': 'E...        74  51.512276
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...        82  51.512430
# 3  [{'id': '4d4ae6fc7a7b7dea34424761', 'name': 'F...        89  51.513624
# 4  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...        89  51.513520
# 5  [{'id': '52e81612bcbc57f1066b7a05', 'name': 'E...        95  51.512555
# 6  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...        98  51.511958
# 7  [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...        98  51.513313
#
#         lng                        id           categories
# 0 -0.127981  4b5344aef964a5200c9527e3   English Restaurant
# 1 -0.127321  54172b0f498e587dba2832f7   English Restaurant
# 2 -0.126908  4c31c371a0ced13a150d146e    Indian Restaurant
# 3 -0.128159  57e6cee7498ec100a83cfd3c  Fried Chicken Joint
# 4 -0.128575  560d0db9498e57efd528f261               Bakery
# 5 -0.126600  4d440bf1c3e5f04d0a219620   English Restaurant
# 6 -0.127846  5980dcd02e26804a157bb9a2   Chinese Restaurant
# 7 -0.129103  59e85fbd6e4650734436499a         Burger Joint

# %%
# Again, recommend the closest restaurant
print("The closest place to go is: ", nearby_food.iloc[0,:]['venue.name'])

#Save the latitude and longitude of this place for restaurant recommendation
# Out:
# The closest place to go is:  The Ivy Restaurant

# %%
################
#Foursquare API get the details of the venue based on the ID
def get_url_detail(venue_id):
    url_d = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
        venue_id,
        CLIENT_ID, 
        CLIENT_SECRET,
        VERSION)
    venue_detail = requests.get(url_d).json()
    
    return venue_detail

# %%
################
#This is how to get the details of one food venue
def get_one_venue(venue_detail):
    
    a = venue_detail['response']['venue']['name']
    b = venue_detail['response']['venue']['rating']
    c = venue_detail['response']['venue']['likes']['count']
    d = venue_detail['response']['venue']['price']['tier']
    list_ = [a, b, c, d]
    
    return list_

# %%
#Create a new dataframe that with name and ratings etc. 
#To combine with the previous one with location information
# filter columns
food_venue_details = []
for i in range (len(nearby_food_filtered)):
    venue_row = nearby_food_filtered.iloc[i, :]
    id_ = venue_row['venue.id']
    #print(id_)
    venue_detail = get_url_detail(id_)

    list_of_venues = get_one_venue(venue_detail)
    print(list_of_venues)
    
    food_venue_details.append(list_of_venues)

    #food_venue_details
# Out:
# ['The Ivy Restaurant', 8.5, 171, 3]
# ['Tredwells', 7.6, 57, 4]
# ['Dishoom', 9.2, 2239, 2]
# ["Chick 'n' Sours", 8.0, 146, 1]
# ['Fabrique', 9.2, 128, 1]
# ["Bill's Restaurant", 7.9, 246, 2]
# ["P. F. Chang's", 8.0, 43, 1]
# ['Shake Shack Soho', 7.8, 49, 1]

# %%
food_venue_details
# Out:
# [['The Ivy Restaurant', 8.5, 171, 3],
#  ['Tredwells', 7.6, 57, 4],
#  ['Dishoom', 9.2, 2239, 2],
#  ["Chick 'n' Sours", 8.0, 146, 1],
#  ['Fabrique', 9.2, 128, 1],
#  ["Bill's Restaurant", 7.9, 246, 2],
#  ["P. F. Chang's", 8.0, 43, 1],
#  ['Shake Shack Soho', 7.8, 49, 1]]

# %%
cols = ['name','rating','likes_count','price_tier']
df_food_venue_details = pd.DataFrame(food_venue_details, columns=cols)
df_food_venue_details
# Out:
#                  name  rating  likes_count  price_tier
# 0  The Ivy Restaurant     8.5          171           3
# 1           Tredwells     7.6           57           4
# 2             Dishoom     9.2         2239           2
# 3     Chick 'n' Sours     8.0          146           1
# 4            Fabrique     9.2          128           1
# 5   Bill's Restaurant     7.9          246           2
# 6       P. F. Chang's     8.0           43           1
# 7    Shake Shack Soho     7.8           49           1

# %%
# Combine all the information of the food venues together
# Merging df_food_venue_details with nearby_food_filtered
df_food = pd.merge(df_food_venue_details, nearby_food_filtered, on='name')
#df_food
df_food_clean = df_food.drop(['categories_','id','serialNum'], axis = 1)

# %% [markdown]
# ### 3.4. Cluster the restaurant into 5 clusters Recommed based on location, number of likes and category

# %%
#Prepare the dataframe for clustering (string cannot be read. Use onehot coding)
#make index a column for later retrieve the name of restaurant
#Drop column categories for k clustering
df_cluster = df_food.drop(['name','categories_','categories','id','serialNum'], axis = 1)
df_cluster
# Out:
#    rating  likes_count  price_tier  distance        lat       lng
# 0     8.5          171           3         7  51.512800 -0.127981
# 1     7.6           57           4        74  51.512276 -0.127321
# 2     9.2         2239           2        82  51.512430 -0.126908
# 3     8.0          146           1        89  51.513624 -0.128159
# 4     9.2          128           1        89  51.513520 -0.128575
# 5     7.9          246           2        95  51.512555 -0.126600
# 6     8.0           43           1        98  51.511958 -0.127846
# 7     7.8           49           1        98  51.513313 -0.129103

# %%
# set number of clusters
kclusters = 3

#manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_cluster)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 1, 0, 0, 0, 2, 2], dtype=int32)

# %%
# add clustering labels
df_food_clean.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
df_food_clean
# Out:
#    Cluster Labels                name  rating  likes_count  price_tier  \
# 0               0  The Ivy Restaurant     8.5          171           3
# 1               2           Tredwells     7.6           57           4
# 2               1             Dishoom     9.2         2239           2
# 3               0     Chick 'n' Sours     8.0          146           1
# 4               0            Fabrique     9.2          128           1
# 5               0   Bill's Restaurant     7.9          246           2
# 6               2       P. F. Chang's     8.0           43           1
# 7               2    Shake Shack Soho     7.8           49           1
#
#    distance        lat       lng           categories
# 0         7  51.512800 -0.127981   English Restaurant
# 1        74  51.512276 -0.127321   English Restaurant
# 2        82  51.512430 -0.126908    Indian Restaurant
# 3        89  51.513624 -0.128159  Fried Chicken Joint
# 4        89  51.513520 -0.128575               Bakery
# 5        95  51.512555 -0.126600   English Restaurant
# 6        98  51.511958 -0.127846   Chinese Restaurant
# 7        98  51.513313 -0.129103         Burger Joint

# %%
# create map
map_clusters = folium.Map(location=[venue_latitude, venue_longitude], zoom_start=16)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_food_clean['lat'], df_food_clean['lng'], df_food_clean['name'], df_food_clean['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=1).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3.4b. Study the clusters

# %%
df_food_clean.sort_values(by=['Cluster Labels'])
# Out:
#    Cluster Labels                name  rating  likes_count  price_tier  \
# 0               0  The Ivy Restaurant     8.5          171           3
# 3               0     Chick 'n' Sours     8.0          146           1
# 4               0            Fabrique     9.2          128           1
# 5               0   Bill's Restaurant     7.9          246           2
# 2               1             Dishoom     9.2         2239           2
# 1               2           Tredwells     7.6           57           4
# 6               2       P. F. Chang's     8.0           43           1
# 7               2    Shake Shack Soho     7.8           49           1
#
#    distance        lat       lng           categories
# 0         7  51.512800 -0.127981   English Restaurant
# 3        89  51.513624 -0.128159  Fried Chicken Joint
# 4        89  51.513520 -0.128575               Bakery
# 5        95  51.512555 -0.126600   English Restaurant
# 2        82  51.512430 -0.126908    Indian Restaurant
# 1        74  51.512276 -0.127321   English Restaurant
# 6        98  51.511958 -0.127846   Chinese Restaurant
# 7        98  51.513313 -0.129103         Burger Joint

# %%
# Normalize the dataframe and do clustering again
#Normalize the dataframe
from sklearn import preprocessing

x = df_cluster
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_cluster_n = pd.DataFrame(x_scaled)

df_cluster_n
# Out:
#         0         1         2         3         4         5
# 0  0.5625  0.058288  0.666667  0.000000  0.505006  0.448026
# 1  0.0000  0.006375  1.000000  0.736264  0.190627  0.711905
# 2  1.0000  1.000000  0.333333  0.824176  0.283067  0.876893
# 3  0.2500  0.046903  0.000000  0.901099  1.000000  0.377124
# 4  1.0000  0.038707  0.000000  0.901099  0.937351  0.210889
# 5  0.1875  0.092441  0.333333  0.967033  0.357891  1.000000
# 6  0.2500  0.000000  0.000000  1.000000  0.000000  0.502266
# 7  0.1250  0.002732  0.000000  1.000000  0.813213  0.000000

# %%
# Clustering again
# set number of clusters
kclusters = 3

#manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_cluster_n)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 2, 0, 0, 1, 1, 0], dtype=int32)

# %%
#df_food_venue_details.insert(0, 'Cluster Labels', kmeans.labels_)
df_food_venue_details.sort_values(by=['Cluster Labels'])
# Out:
#    Cluster Labels                name  rating  likes_count  price_tier
# 3               0     Chick 'n' Sours     8.0          146           1
# 4               0            Fabrique     9.2          128           1
# 7               0    Shake Shack Soho     7.8           49           1
# 0               1  The Ivy Restaurant     8.5          171           3
# 1               1           Tredwells     7.6           57           4
# 5               1   Bill's Restaurant     7.9          246           2
# 6               1       P. F. Chang's     8.0           43           1
# 2               2             Dishoom     9.2         2239           2
