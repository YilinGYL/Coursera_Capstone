# %% [markdown]
# ### Import Libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import csv # library to handle csv files

import geocoder as geocoder
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

from bs4 import BeautifulSoup
import requests

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### 1. London neighbbourhood informatio - Scraping data from Wikipedia

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/List_of_areas_of_London')
raw = dfs[1]
raw.head()

df1 = raw.drop(raw.index[0])
df1.columns = ['Location','London_borough','Post town','Postcode district','Dial Code','OS grid ref']
df1.head()
# Out:
#       Location                     London_borough       Post town  \
# 1   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 2        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 3    Addington                         Croydon[8]         CROYDON
# 4   Addiscombe                         Croydon[8]         CROYDON
# 5  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial Code OS grid ref
# 1               SE2       020    TQ465785
# 2            W3, W4       020    TQ205805
# 3               CR0       020    TQ375645
# 4               CR0       020    TQ345665
# 5         DA5, DA14       020    TQ478728

# %%
# Drop the unnecessary information and clean data
df = df1.drop(['Dial Code','OS grid ref'], axis = 1)
df = df.reindex()
df.head()
# Out:
#       Location                     London_borough       Post town  \
# 1   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 2        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 3    Addington                         Croydon[8]         CROYDON
# 4   Addiscombe                         Croydon[8]         CROYDON
# 5  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district
# 1               SE2
# 2            W3, W4
# 3               CR0
# 4               CR0
# 5         DA5, DA14

# %%
df.shape
# Out:
# (533, 4)

# %% [markdown]
# get logitude and altitude of London Neighbourhood

# %%
def getLatLong(row):
    #print('post :{}'.format(row[:]))
    #print('neigh :{}'.format(row[1]))
    # initialize your variable to None
    lat_lng_coords = None
    search_query = '{}, London,UK'.format(row)
    # loop until you get the coordinates
    try:
        while(lat_lng_coords is None):
            #g = geocoder.here(search_query,app_id=app_id,app_code=app_code)
            g = geocoder.arcgis(search_query)
            lat_lng_coords = g.latlng
            #print('FIRST')
    except IndexError:
        latitude = 0.0
        longitude = 0.0
        print('BACKUP')
        return [latitude,longitude]

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    print(latitude, longitude)
    return [latitude, longitude]

# %%
# coords_list = df['Postcode district'].apply(getLatLong).tolist()
# Out:
# 51.492450000000076 0.12127000000003818
# 51.51324000000005 -0.2674599999999714
# 51.38475500000004 -0.051498623999975734
# 51.38475500000004 -0.051498623999975734
# 51.452067760578885 0.1722299153689439
# 51.50642000000005 -0.1272099999999341
# 51.51200000000006 -0.08057999999994081
# 51.51651000000004 -0.11967999999995982
# 51.50642000000005 -0.1272099999999341
# 51.41009000000008 -0.05682999999993399
# 51.523610000000076 -0.09876999999994496
# 51.27172802817503 0.07471050704375404
# 51.56393000000003 -0.12944999999996298
# 51.58370000000008 0.17476000000004888
# 51.615680000000054 -0.2451099999999542
# 51.63429000000008 -0.13365999999996347
# 51.44822000000005 -0.1483899999999494
# 1   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 2        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 3    Addington                         Croydon[8]         CROYDON
# 4   Addiscombe                         Croydon[8]         CROYDON
# 5  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district   Latitude  Longitude
# 1               SE2  51.513240  -0.267460
# 2            W3, W4  51.384755  -0.051499
# 3               CR0  51.384755  -0.051499
# 4               CR0  51.452068   0.172230
# 5         DA5, DA14  51.506420  -0.127210

# %%
# Save it to a CSV file
df.to_csv(r'./LondonPostCodeDistrict.csv')

# %% [markdown]
# ### 2. Must-visit places information - from one (or multiple) review article https://foursquare.com/gmissawa/list/places-to-visit-in-london

# %%
#Get the data with beautifulsoup
source = requests.get('https://foursquare.com/gmissawa/list/places-to-visit-in-london').text
soup = BeautifulSoup(source,'lxml')
#print(soup.prettify())

# %%
# Scraping the venue information
match = soup.find('div', class_='venueInfo')
#print(match.prettify())

# %%
# Scraping trial, to find all the information in the first entry
# venue_name = match.find('p', class_ = 'venueName')
# rating = match.find('div', class_ = 'rating')
# category = match.find('span', class_ = "unlinkedCategory")

# print (venue_name.text)
# print(rating.text)
# print(category.text)

# %%
# Save as csv
csv_file = open('London_venue.csv','w')
csv_writer = csv.writer(csv_file, lineterminator='\n')
csv_writer.writerow(['Venue Name', 'Category', 'Rating', 'Venue ID'])

# Loop through all the venues and save the inforamtion into a list
for match in soup.find_all('div', class_='venueInfo'):
    
    venue_name = match.find('p', class_ = 'venueName').text
    category = match.find('span', class_ = "unlinkedCategory").text
#     print (venue_name)
#     print(category)
    
    try:
        rating = match.find('div', class_ = 'rating').text
#         print(rating)
        venue_src = match.find('a')['href']
        venue_id = venue_src.split('/')[3]
#         print(venue_id)
    except Exception as e:
        rating = 'NaN'
#         print('NaN')
        veneue_id = 'NaN'
    # Save as csv
    csv_writer.writerow([venue_name, category, rating, venue_id])

csv_file.close()

# %%
# Read csv file as pandas dataframe
df_ln = pd.read_csv("London_venue.csv", encoding = "ISO-8859-1")
#df_ln.head

# %% [markdown]
# #### Get more informaiton from Foursquare based on venue ID (This part can be skipped, since the inforamtion are saved into a .csv file)
#
# The webscraping step has got some venue id that corresponse to the same venue, the venue informaiton of 78 is received. Due to the number of requests for Foursquare is limited, in this work, we will use 78 popular venunes' information as an case study. This part can be improved in the future to include all the poluplar venues.

# %%
# Directly read from the csv file, the code used to generate the csv file is in Appendix Section
df_venue = pd.read_csv("df_venue.csv")
df_venue.shape
# Out:
# (78, 7)

# %% [markdown]
# ### This is the second part of data of popular attractions in London with the latitude and logitude, number of likes, name of the venue and postcode.

# %%
df_venue
# Out:
#     Unnamed: 0  location.lat  location.lng location.postalCode  \
# 0           37     51.512726     -0.201859             W11 2QD
# 1           19     51.512841     -0.127896            WC2H 9ND
# 2           12     51.512211     -0.123566            WC2E 8HB
# 3           32     51.519800     -0.093969            EC2Y 8DS
# 4           36     51.519855     -0.093942            EC2Y 8DS
# 5            5     51.519009     -0.126437            WC1B 3DG
# 6            8     51.500956     -0.143123            SW1A 1AA
# 7           20     51.541475     -0.146084             NW1 8AF
# 8           34     51.502079     -0.129305            SW1A 2AQ
# 9           10     51.511977     -0.122799            WC2E 8RF
# 10           0     51.500620     -0.124578            SW1A 0AA
# 11          30     51.555247     -0.108361              N5 1BU
# 12          37     51.515108     -0.127132            WC2H 8JR
# 13          36     51.504656     -0.143788            SW1A 1BW
# 14          27     51.477521      0.000858            SE10 9NF
# 15          14     51.506599     -0.081507             SE1 2JH
# 16          29     51.403235     -0.337400             KT8 9AU
# 17          33     51.515647     -0.090997            EC2V 5BQ
# 18          16     51.507781     -0.162392              W2 2TP
# 19          24     51.495985     -0.108642             SE1 6HZ
# 20          32     51.510519     -0.130098            WC2H 7NA
# 21          12     51.531371     -0.126022             NW1 2QP
# 22          44     51.512001     -0.121308            WC2E 7BB
# 23          33     51.510599     -0.131149            WC2H 7DG
# 24          11     51.523017     -0.154361             NW1 5LR
# 25          45    -22.887130    -47.059763                 NaN
# 26           7     51.513446     -0.158270                 NaN
# 27          41     51.512300     -0.150738             W1K 6JP
# 28          41     51.354694     -0.467987            KT13 0SL
# 29          22     51.514314     -0.126824            WC2H 9EU
# 30          31     51.505069     -0.150557             W1K 1LB
# 31          32     51.508412     -0.108664             SE1 9PH
# 32          13     51.508647     -0.175830             W11 1PN
# 33           9     51.509961     -0.134652             W1D 1NN
# 34          38     51.532006     -0.124216              N1 9AL
# 35          19     51.512829     -0.202206                 W11
# 36          20     51.514331     -0.204073                 W11
# 37           5     51.511775     -0.123010            WC2E 8RF
# 38           6     51.513416     -0.131648             W1D 4HT
# 39          21     51.509109     -0.139476             W1J 0BD
# 40          15     51.501122     -0.177417             SW7 2AP
# 41          16     51.477748     -0.296631             TW9 3AB
# 42          28     51.477322     -0.000869            SE10 8XJ
# 43          49     51.513083     -0.121968            WC2E 9DD
# 44          44     51.490689     -0.158916             SW3 4RY
# 45          30     51.502181     -0.119616             SE1 7PB
# 46          25     51.492500     -0.157435            SW1W 8EG
# 47           8     51.515286     -0.132209             W1D 3QA
# 48           9     51.511571     -0.159421              W2 2UH
# 49          35     51.503253     -0.132995            SW1A 2BJ
# 50           6     51.513877     -0.098426            EC4M 8AD
# 51          29     51.480925     -0.191542             SW6 1HS
# 52          33     51.179060     -1.826198             SP4 7DE
# 53           1     51.490772     -0.126965            SW1P 4RG
# 54          23     51.507704     -0.099456             SE1 9TG
# 55          25     51.507446     -0.092978             SE1 9EF
# 56          35     51.506912     -0.194801              W8 7LN
# 57           3     51.521265     -0.109801            EC1N 7TR
# 58           6     51.509719     -0.125943            WC2N 4HS
# 59          25     51.511718     -0.125695            WC2E 9EB
# 60          26     51.523664     -0.158224             NW1 6XE
# 61           1     51.503287     -0.119594             SE1 7PB
# 62          31     51.510134     -0.086048            EC3R 8AH
# 63           2     51.528343     -0.118558            WC1X 9NB
# 64          38     51.507078     -0.141627             W1J 9BR
# 65           8     51.510941     -0.127052            WC2N 4AP
# 66          36     51.523702     -0.158227             NW1 6XE
# 67          26     51.505598     -0.122142            SW1A 2HR
# 68           7     51.505550     -0.075338             SE1 2UP
# 69           3     51.508248     -0.076261            EC3N 4AB
# 70           2     51.507987     -0.128048            WC2N 5DX
# 71          34     51.496369     -0.172388             SW7 2RL
# 72          45     51.689539     -0.419315            WD25 7LR
# 73          26     51.556209     -0.279572             HA9 0WS
# 74          46     51.507394     -0.221357             W12 7SH
# 75           4     51.499356     -0.127357            SW1P 3PA
# 76           0     51.484029     -0.604441             SL4 1NJ
# 77           7     51.535714     -0.155724             NW1 4RY
#
#                                                  name  rating  likes.count
# 0                                             Alice's     8.2            9
# 1                                 Ambassadors Theatre     8.1           73
# 2                                 Apple Covent Garden     9.0         2180
# 3                                Barbican Art Gallery     9.2          273
# 4                                     Barbican Centre     9.3         1763
# 5                                      British Museum     9.4         8498
# 6                                   Buckingham Palace     8.7         6627
# 7                                  Camden Lock Market     9.1         3789
# 8   Churchill War Rooms (Churchill Museum & Cabine...     9.1          503
# 9                                Covent Garden Market     9.3         3409
# 10  Elizabeth Tower (Big Ben) (Big Ben (Elizabeth ...     9.3         6439
# 11                                   Emirates Stadium     8.8         2200
# 12                                   Forbidden Planet     9.1          971
# 13                                         Green Park     9.3         2606
# 14                                     Greenwich Park     9.6         1358
# 15                    HMS Belfast (HMS Belfast (C35))     8.4          262
# 16                               Hampton Court Palace     9.3          775
# 17                                Hawksmoor Guildhall     8.7          294
# 18                                          Hyde Park     9.6        11445
# 19                                Imperial War Museum     9.0          879
# 20                                   Leicester Square     8.7         2335
# 21  London St Pancras International Railway Statio...     8.9         2917
# 22                            London Transport Museum     8.8          552
# 23                                        M&M's World     8.4         2771
# 24                                    Madame Tussauds     8.7         2463
# 25                                  Maravilhas do Lar     8.2          224
# 26                                        Marble Arch     8.8         1591
# 27                                         Maze Grill     7.8          258
# 28                                Mercedes-Benz World     8.6          164
# 29                            Monmouth Coffee Company     9.2         1476
# 30                                               Nobu     8.9          520
# 31                                          OXO Tower     8.0          124
# 32                                   Peter Pan Statue     8.2           74
# 33                                  Piccadilly Circus     9.0         6895
# 34                                        Platform 9¾     8.0         1223
# 35                                    Portobello Road     8.7          182
# 36                             Portobello Road Market     8.9         3394
# 37                                       Punch & Judy     6.8          209
# 38                           Ronnie Scott's Jazz Club     9.3          590
# 39                              Royal Academy of Arts     9.2         1349
# 40                                  Royal Albert Hall     9.5         2536
# 41  Royal Botanic Gardens (Royal Botanic Gardens, ...     9.5         1368
# 42                                  Royal Observatory     8.5          719
# 43                                  Royal Opera House     9.3         1045
# 44                                    Saatchi Gallery     9.3         1380
# 45                           Sea Life London Aquarium     7.2          494
# 46                                      Sloane Square     8.9          836
# 47                                        Soho Square     8.7          739
# 48                                   Speakers' Corner     7.1           99
# 49                                    St James's Park     9.5         3090
# 50                                St Paul's Cathedral     9.2         2018
# 51                                    Stamford Bridge     8.6         1870
# 52                                         Stonehenge     8.7         1695
# 53                                       Tate Britain     9.2         1688
# 54                                        Tate Modern     9.2         8008
# 55                                         The Anchor     7.5          567
# 56                                 The Churchill Arms     8.9          718
# 57                                 The Craft Beer Co.     8.6          430
# 58                                           The Harp     8.8          687
# 59                                    The Lamb & Flag     8.5          454
# 60                           The London Beatles Store     7.3           97
# 61                                     The London Eye     9.2         6506
# 62                                       The Monument     8.4          561
# 63                                   The Queen's Head     8.5          216
# 64                                    The Ritz London     9.0          454
# 65                                      The Salisbury     7.3          178
# 66                         The Sherlock Holmes Museum     8.2          880
# 67                             The Tattershall Castle     7.6          251
# 68                                       Tower Bridge     9.5         5471
# 69                                    Tower of London     9.2         4842
# 70                                   Trafalgar Square     9.2         4483
# 71                   Victoria and Albert Museum (V&A)     9.4         4957
# 72  Warner Bros. Studio Tour London - The Making o...     9.6         2837
# 73                                    Wembley Stadium     8.9         2507
# 74                                   Westfield London     8.8         4575
# 75                                  Westminster Abbey     9.2         1514
# 76                                     Windsor Castle     9.3         1200
# 77                                     ZSL London Zoo     8.4         1025

# %% [markdown]
# ### Appendix: Code used to do webscraping and making foursquare API requests

# %% [markdown]
# #### Read the information from csv file (generated from Foursquare requests)

# %%
# CLIENT_ID = '' # your Foursquare ID
# CLIENT_SECRET = '' # your Foursquare Secret
# VERSION = '20180604'
# LIMIT = 30
# print('Your credentails:')
# print('CLIENT_ID: ' + CLIENT_ID)
# print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
# # Loop through df_ln datafrmae limited to first 45 items (each account has 50 request/day)
# df_4s = pd.DataFrame([])
# for i in range(136):
#     venue_id = df_ln['Venue ID'][i]
#     #print(venue_id)
    
#     url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
#     #print(url)
    
#     #Request from foursqure
#     result = requests.get(url).json()
#     #print(result)
    
#     #assign relevant part of JSON to venue
#     venues = result['response']['venue']
#     dataframe = json_normalize(venues)
    
#     df_4s = df_4s.append(dataframe)

# #print(df_4s.head())

# %%
# data1 = pd.read_csv("place1to39.csv")
# data2 = pd.read_csv("place40to89.csv")
# data3 = pd.read_csv("place90to136.csv")
# columnsnew =['location.lat','location.lng', 'location.postalCode', 'name', 'rating', 'likes.count']
# data1_=data1[columnsnew]
# data2_=data2[columnsnew]
# data3_=data3[columnsnew]
# print('size of data1, data2, data3:', data1_.shape, data2_.shape, data3_.shape)

# dfall = data1_.append(data2_)
# dfall = dfall.append(data3_)

# print('size of dfall:', dfall.shape)

# #Remove duplicates
# dfall.sort_values('name', inplace=True)
# dfall.drop_duplicates(subset ="name", 
#                      keep = False, inplace = True) 
# dfall.shape
# # Save to a csv 
# dfall.to_csv(r'./df_venue.csv')

# %%
# # Save the requests into csv file 
# df_4s.to_csv(r'./place45.csv')
